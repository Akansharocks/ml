# %% [markdown]
# <a href="https://colab.research.google.com/github/Akansharocks/ml/blob/main/api_access.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pandas as pd

# %%
api_key = '71e980be93c14017aea8891325a6d5a0'

# %%
params = {
    'q': 'India',
    'language': 'en',
    'sortBy': 'publishedAt',
    'apiKey': api_key
}
url = 'https://newsapi.org/v2/everything'

# %%
response = requests.get(url, params=params)
data = response.json()
print(data)
# Out:
# {'status': 'ok', 'totalResults': 23320, 'articles': [{'source': {'id': 'the-times-of-india', 'name': 'The Times of India'}, 'author': 'ET Online', 'title': "India Weather Today: Uttarakhand landslide alert, Gujarat flood risk in focus; check IMD's forecast for your city", 'description': 'India faces intensified monsoon conditions, prompting the IMD to issue alerts for landslides in Uttarakhand and severe flooding in Gujarat. Konkan, Goa, and Maharashtra Ghat regions brace for extremely heavy rainfall, increasing risks of slope failures and ur…', 'url': 'https://economictimes.indiatimes.com/news/india/india-weather-today-uttarakhand-landslide-alert-gujarat-flood-risk-in-focus-check-imds-forecast-for-your-city/articleshow/122287027.cms', 'urlToImage': 'https://img.etimg.com/thumb/msid-122287067,width-1200,height-630,imgsize-62332,overlay-economictimes/articleshow.jpg', 'publishedAt': '2025-07-07T02:03:54Z', 'content': 'As monsoon intensifies across India, the India Meteorological Depar
# ...

# %%
articles = data['articles']

# %%
# Create DataFrame
df = pd.DataFrame(articles)
df.head()
# Out:
#                                               source              author  \
# 0  {'id': 'the-times-of-india', 'name': 'The Time...           ET Online
# 1               {'id': None, 'name': 'BusinessLine'}  KS Badri Narayanan
# 2                   {'id': None, 'name': 'Livemint'}                mint
# 3        {'id': None, 'name': 'Mypeoplesreview.com'}     People's Review
# 4               {'id': None, 'name': 'BusinessLine'}  KS Badri Narayanan
#
#                                                title  \
# 0  India Weather Today: Uttarakhand landslide ale...
# 1  Why these 4 railway and shipping stocks will b...
# 2  Sebi’s Jane Street interim order made India’s ...
# 3  Alam gets clean chit; will victim Chamar get j...
# 4  Watch out these 20 stocks including Adani Ente...
#
#                                          description  \
# 0  India faces intensified monsoon conditions, pr...
# 1  Shipping Corporation, Cochin Shipyard, Texmaco...
# ...
